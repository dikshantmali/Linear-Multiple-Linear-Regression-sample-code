# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
link = 'file:///home/dikshant/Documents/Kangaroo%20Rooms%20Training/iris.data'

# %%
df = pd.read_csv(link)

# %%
df
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
df.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width',
#        'species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
df['species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: species, dtype: int64

# %%
df.plot(kind='scatter',x='sepal length',y='sepal width')

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid');
sns.FacetGrid(df,hue='species',size=4).map(plt.scatter,'sepal length','sepal width').add_legend();
plt.show()
